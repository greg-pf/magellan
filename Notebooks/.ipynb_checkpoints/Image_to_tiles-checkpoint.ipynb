# %%
import math
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np
import skimage
from skimage import color, transform
import glob

# %matplotlib inline
plt.rcParams['figure.figsize'] = 20, 10
plt.axis('off')

imgpath = glob.glob("./map.png")[0]
img = mpimg.imread(imgpath)

plt.imshow(img);

# %%
def max_sq_size(img, n):
    height = len(img)
    width = len(img[0])
    
    px = int(math.ceil(math.sqrt(n * width/height)))
    if (math.floor(px * height/width) * px < n):
        sx = height / int(math.ceil(px * height/width))
    else:
        sx = width / px
    
    py = int(math.ceil(math.sqrt(n * height/width)))
    if (math.floor(py * width/height)* py < n):
            sy = width / int(math.ceil(py * width/height))
    else:
            sy = height / py
            
    return min(sx, sy)

# %%
# create a square tiling of the image
def img_to_sqs(img, n_tiles):
    side_length = max_sq_size(img, n_tiles)
    tiles = []
    for y in range(0, len(img)-side_length + 1, side_length):
        tiles += [[]]
        for x in range(0, len(img[0])-side_length + 1, side_length):
            tiles[y/side_length] += [img[y:y+side_length, x:x+side_length]]
    return tiles

# %%
for y,row in enumerate(img_to_sqs(img, 50)):
    plt.figure()
    tiles = len(row)
    for x,tile in enumerate(row):
        plt.subplot(1, tiles, x+1)
        plt.axis('off')
        plt.imshow(tile, interpolation='nearest')

# %%
# create a triangulare tiling of the image
def img_to_tris(img, side_length):
    height = int(math.sqrt(side_length**2 - (side_length / 2)**2))
    tiles = []
    mask = generate_tri_mask(side_length, height)
    for y in range(0, len(img)-height + 1, height):
        tiles += [[]]
        for x in range(0, len(img[0])-side_length + 1, side_length / 2):
            mask = transform.rotate(mask, 180)
            tiles[y/height] += [img[y:y+height, x:x+side_length] * mask]
    return tiles

# %%
# a boolean mask in the shape of an isosceles triangle of given base and height
def generate_tri_mask(base, height):
    mask = np.zeros((height, base, 4))
    center = base / 2
    for y in range(height):
        width = int((y / float(height)) * base)
        mask[y][center - (width / 2):center + (width / 2)] = [1, 1, 1, 1]
    return mask

tri_mask = generate_tri_mask(200, 173)
plt.figure()
plt.imshow(tri_mask)
plt.figure()
plt.imshow(skimage.transform.rotate(tri_mask, 180))

# %%
# a boolean mask in the shape of a regular hexagon with side length s
def generate_hex_mask(s):
    max_width = 2 * s
    min_width = int(math.sqrt(3) * s)
    mask = np.zeros((max_width, min_width, 3))
    center = min_width / 2
    for y in range()

# %%
for y,row in enumerate(img_to_tris(img, 250)):
    plt.figure()
    tiles = len(row)
    for x,tile in enumerate(row):
        plt.subplot(1, tiles, x+1)
        plt.axis('off')
        plt.imshow(tile, interpolation='nearest')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-40-e2fbbc756c37> in <module>()
# ----> 1 for y,row in enumerate(img_to_tris(img, 250)):
#       2     plt.figure()
#       3     tiles = len(row)
#       4     for x,tile in enumerate(row):
#       5         plt.subplot(1, tiles, x+1)
#
# <ipython-input-39-f1afecf62c3c> in img_to_tris(img, side_length)
#       8         for x in range(0, len(img[0])-side_length + 1, side_length / 2):
#       9             mask = transform.rotate(mask, 180)
# ---> 10             tiles[y/height] += np.dstack((img[y:y+height, x:x+side_length], mask))
#      11     return tiles
#
# ValueError: operands could not be broadcast together with shapes (0,) (216,250,4)
